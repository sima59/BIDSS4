# %%
import pandas as pd

# %%
import numpy as np

# %%
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Real_Property_Tax_-_2020'

# %%
pd.read_csv(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-016e417ab6f0> in <module>
# ----> 1 pd.read_csv(df)
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Tax_Revenue_By_Month.csv'

# %%
pd.read_csv(df)
# Out:
#       ID      Month  Calendar Year  Income Tax Estimates & Finals  \
# 0      1       July           2011                            NaN
# 1      2     August           2011                   2.320268e+07
# 2      3  September           2011                   2.748813e+08
# 3      4    October           2011                   6.944227e+07
# 4      5   November           2011                   8.803835e+07
# ..   ...        ...            ...                            ...
# 114  115    January           2021                   5.240746e+08
# 115  116   February           2021                   3.777888e+07
# 116  117      March           2021                   8.047873e+07
# 117  118      April           2021                   5.143920e+08
# 118  119        May           2021                   1.011470e+09
#
#      Sales and Use  Business Use  Business Entity  Real Estate Conveyance  \
# 0              NaN           NaN        381060.92                     NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
df..close.rolling('Total Revenue').min().plot(
    title='Minemum Total Revenue'
)
# Out:
#   File "<ipython-input-8-2f787ec21870>", line 1
#     df..close.rolling('Total Revenue').min().plot(
#        ^
# SyntaxError: invalid syntax

# %%
df.close.rolling('Total Revenue').min().plot(
    title='Minemum Total Revenue'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-cb502eab5d52> in <module>
# ----> 1 df.close.rolling('Total Revenue').min().plot(
#       2     title='Minemum Total Revenue'
#       3 )
#
# AttributeError: 'str' object has no attribute 'close'

# %%
tx = 'C:\\Users\\LG\\Desktop\SUMMER1\\Real_Property_Tax_-_2020.csv'

# %%
pd.read_csv(tx)
# Out:
#         PARCEL CODE                  RESIDENCE           CITY  ZIP CODE  \
# 0             45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 1            150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 2           1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 3            308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 4            311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# ...             ...                        ...            ...       ...
# 343908      3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0
# 343909      3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0
# 343910      3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 343911      3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0
# 343912      3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN
#
#           Value  COUNTY PROPERTY TAX-Due  SOLID WASTE CHARGE  \
# ...

# %%
min=tx.min(total)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2b08ce1b5adb> in <module>
# ----> 1 min=tx.min(total)
#
# AttributeError: 'str' object has no attribute 'min'

# %%
tx.total.min().plot(
    title='Minemum Total Tax'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-4d2c565ebf45> in <module>
# ----> 1 tx.total('Total').min().plot(
#       2     title='Minemum Total Tax'
#       3 )
#
# AttributeError: 'str' object has no attribute 'total'

# %%
tx.total.min().plot(
    title='Minemum Total Tax'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ddf2e2b04ca2> in <module>
# ----> 1 tx.total.min().plot(
#       2     title='Minemum Total Tax'
#       3 )
#
# AttributeError: 'str' object has no attribute 'total'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
plt.hist(Total)
plt.title('Total of the tax')
plt.xlabel('Total')
plt.ylabel('number');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-11f5ff617de9> in <module>
# ----> 1 plt.hist(Total)
#       2 plt.title('Total of the tax')
#       3 plt.xlabel('Total')
#       4 plt.ylabel('number');
#
# NameError: name 'Total' is not defined

# %%
plt.hist(tx)
plt.title('Total of the tax')
plt.xlabel('Total')
plt.ylabel('number');

# %%
min=min(tx.total)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b379d39febda> in <module>
# ----> 1 min=min(tx.total)
#
# AttributeError: 'str' object has no attribute 'total'

# %%
min=min(tx.TOTAL)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-47919e9788f9> in <module>
# ----> 1 min=min(tx.TOTAL)
#
# AttributeError: 'str' object has no attribute 'TOTAL'

# %%
data.Total
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4f9fcbf1783c> in <module>
# ----> 1 data.Total
#
# NameError: name 'data' is not defined

# %%
tx.TOTAL
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1cbad65caa7c> in <module>
# ----> 1 tx.TOTAL
#
# AttributeError: 'str' object has no attribute 'TOTAL'

# %%
data=pd.read_csv(tx)

# %%
print(data)
# Out:
#         PARCEL CODE                  RESIDENCE           CITY  ZIP CODE  \
# 0             45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 1            150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 2           1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 3            308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 4            311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# ...             ...                        ...            ...       ...
# 343908      3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0
# 343909      3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0
# 343910      3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 343911      3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0
# 343912      3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN
#
#           Value  COUNTY PROPERTY TAX-Due  SOLID WASTE CHARGE  \
# ...

# %%
data.total
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-3db63159f056> in <module>
# ----> 1 data.total
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'total'

# %%
data.TOTAL
# Out:
# 0             0.00
# 1             0.00
# 2             0.00
# 3           221.74
# 4          2613.48
#             ...
# 343908      448.87
# 343909    60994.89
# 343910        0.00
# 343911       21.15
# 343912     1952.89
# Name: TOTAL, Length: 343913, dtype: float64

# %%
data.PARCELCODE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-7a9cf1681ae7> in <module>
# ----> 1 data.PARCELCODE
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'PARCELCODE'

# %%
dt='C:\\Users\\LG\\Desktop\SUMMER1\\Real_Property_Tax_-_2020.csv'

# %%
data=pd.read_csv(dt)

# %%
print(data)
# Out:
#            CODE                  RESIDENCE           CITY  ZIP CODE    Value  \
# 0         45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 1        150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 2       1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 3        308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN    20100
# 4        311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN   236900
# ...         ...                        ...            ...       ...      ...
# 343908  3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0    40000
# 343909  3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0  5363000
# 343910  3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 343911  3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0        0
# 343912  3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN   151200
#
# ...

# %%
data.CODE
# Out:
# 0           45986
# 1          150491
# 2         1624601
# 3          308418
# 4          311347
#            ...
# 343908    3811057
# 343909    3815580
# 343910    3835645
# 343911    3806530
# 343912    3826388
# Name: CODE, Length: 343913, dtype: int64

# %%
data.RESIDENCE
# Out:
# 0         NOT A PRINCIPAL RESIDENCE
# 1         NOT A PRINCIPAL RESIDENCE
# 2         NOT A PRINCIPAL RESIDENCE
# 3         NOT A PRINCIPAL RESIDENCE
# 4         NOT A PRINCIPAL RESIDENCE
#                     ...
# 343908          PRINCIPAL RESIDENCE
# 343909    NOT A PRINCIPAL RESIDENCE
# 343910    NOT A PRINCIPAL RESIDENCE
# 343911    NOT A PRINCIPAL RESIDENCE
# 343912    NOT A PRINCIPAL RESIDENCE
# Name: RESIDENCE, Length: 343913, dtype: object

# %%
data.describe()
# Out:
#                CODE       ZIP CODE         Value       TAX-Due   WASTE-CHARGE  \
# count  3.439130e+05  324125.000000  3.439130e+05  3.439130e+05  343913.000000
# mean   1.937785e+06   20868.652890  5.811394e+05  5.675616e+03     264.230656
# std    1.109963e+06      62.088914  2.814134e+06  2.756035e+04    1086.661151
# min    1.100000e+01   12040.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    9.964400e+05   20851.000000  2.500000e+05  2.418860e+03      31.190000
# 50%    1.929071e+06   20874.000000  3.868000e+05  3.784410e+03     222.860000
# 75%    2.906532e+06   20901.000000  5.994000e+05  5.827260e+03     329.860000
# max    3.848226e+06   37215.000000  4.876059e+08  4.833150e+06  277605.200000
#
#             STATETAX         TOTAL       CREDITS     TOTAL-DUE
# count  343913.000000  3.439130e+05  3.439130e+05  3.439130e+05
# mean      649.614523  7.049641e+03  5.824979e+02  6.467143e+03
# std      3151.949184  3.334316e+04  4.018380e+03  3.284644e+04
# ...

# %%
data['TOTAL'].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0             0.00
# 1             0.00
# 2             0.00
# 3           221.74
# 4          2613.48
#             ...
# 343908      448.87
# 343909    60994.89
# 343910        0.00
# 343911       21.15
# 343912     1952.89
# Name: TOTAL, Length: 343913, dtype: float64>

# %%
data[data["RESIDENCE"] == "PRINCIPAL RESIDENCE"]
# Out:
#            CODE            RESIDENCE            CITY  ZIP CODE   Value  \
# 35       932938  PRINCIPAL RESIDENCE        DAMASCUS   20872.0  499833
# 40       944787  PRINCIPAL RESIDENCE        DAMASCUS   20872.0  404467
# 52      1324403  PRINCIPAL RESIDENCE   SILVER SPRING   20902.0  405467
# 54      2949440  PRINCIPAL RESIDENCE       ROCKVILLE   20852.0    8000
# 56      1329644  PRINCIPAL RESIDENCE   SILVER SPRING   20902.0  359633
# ...         ...                  ...             ...       ...     ...
# 343870  3807740  PRINCIPAL RESIDENCE      CLARKSBURG       NaN  364067
# 343874  3808915  PRINCIPAL RESIDENCE  NORTH BETHESDA   20852.0  640000
# 343887  3801663  PRINCIPAL RESIDENCE        BETHESDA   20814.0  536667
# 343894  3803800  PRINCIPAL RESIDENCE             NaN       NaN  378767
# 343908  3811057  PRINCIPAL RESIDENCE        BETHESDA   20814.0   40000
#
#          TAX-Due  WASTE-CHARGE  STATETAX    TOTAL  CREDITS   TOTAL-DUE
# ...

# %%
data[data["RESIDENCE"] == "NOT A PRINCIPAL RESIDENCE"]
# Out:
#            CODE                  RESIDENCE           CITY  ZIP CODE    Value  \
# 0         45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 1        150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 2       1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 3        308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN    20100
# 4        311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN   236900
# ...         ...                        ...            ...       ...      ...
# 343907  3806951  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0        0
# 343909  3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0  5363000
# 343910  3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 343911  3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0        0
# 343912  3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN   151200
#
# ...

# %%
data["CREDIT"].plot(kind='hist',bins=100)
plt.xlable('CODE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CREDIT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-8cb03a797c99> in <module>
# ...

# %%
import matplotlib.pyplot as plt
data["CREDIT"].plot(kind='hist',bins=100)
plt.xlable('CODE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CREDIT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-ab42be9bc87a> in <module>
# ...

# %%
import matplotlib.pyplot as plt
data["TOTAL"].plot(kind='hist',bins=100)
plt.xlable('CODE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-20cf0239c707> in <module>
#       1 import matplotlib.pyplot as plt
#       2 data["TOTAL"].plot(kind='hist',bins=100)
# ----> 3 plt.xlable('CODE')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
import matplotlib.pyplot as plt
data["RESIDENCE"].plot(kind='hist',bins=100)
plt.xlable("NOT A PRINCIPAL RESIDENCE")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-58ffec7cb3d8> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 data["RESIDENCE"].plot(kind='hist',bins=100)
#       3 plt.xlable("NOT A PRINCIPAL RESIDENCE")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
# ...

# %%
plot_data=data[data["RESIDENCE"]]=="NOT A PRINCIPAL RESIDENCE"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-68d7e7b39459> in <module>
# ----> 1 plot_data=data[data["RESIDENCE"]]=="NOT A PRINCIPAL RESIDENCE"
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]

# %%
plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]
plot_data=plot_data.groupby("TOTAL")
plot_data.sort_values()[-100].plot(kind='bar')
plt.title("TOTAL TAX")
plt.ylable("PROPERTY TYPE")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-cc21b835840d> in <module>
#       1 plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]
# ----> 2 plot_data=plot_data.groupby("TOTAL-DUE")
#       3 plot_data.sort_values()[-100].plot(kind='bar')
#       4 plt.title("TOTAL TAX-DUE")
#       5 plt.ylable("PROPERTY TYPE")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ...

# %%
plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]
plot_data=plot_data.groupby("TOTAL")
plot_data.sort_values()[-10].plot(kind='bar')
plt.title("TOTAL TAX")
plt.ylable("PROPERTY TYPE")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-6a65a1907d99> in <module>
#       1 plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]
#       2 plot_data=plot_data.groupby("TOTAL")
# ----> 3 plot_data.sort_values()[-100].plot(kind='bar')
#       4 plt.title("TOTAL TAX")
#       5 plt.ylable("PROPERTY TYPE")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]
plot_data=plot_data.groupby("TOTAL")
plot_data.sort_values()[-10].plot(kind='bar')
plt.title("TOTAL TAX")
plt.ylable("PROPERTY TYPE")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-e03b50dfa970> in <module>
#       1 plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]
#       2 plot_data=plot_data.groupby("TOTAL")
# ----> 3 plot_data.sort_values()[-10].plot(kind='bar')
#       4 plt.title("TOTAL TAX")
#       5 plt.ylable("PROPERTY TYPE")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
plot_data=data[data["RESIDENCE"]=="NOT A PRINCIPAL RESIDENCE"]
plot_data=plot_data.groupby("TOTAL")
plot_data.plot(kind='bar')
plt.title("TOTAL TAX")
plt.ylable("PROPERTY TYPE")
# Out:
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
import matplotlib.pyplot as plt
data["RESIDENCE"].plot(kind='hist',bins=100)
plt.xlable("TOTAL")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48e8c7a0558c> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 data["RESIDENCE"].plot(kind='hist',bins=100)
#       3 plt.xlable("TOTAL")
#
# NameError: name 'data' is not defined

# %%
dt='C:\\Users\\LG\\Desktop\SUMMER1\\Real_Property_Tax_-_2020.csv'

# %%
data=pd.read_csv(tx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1118f55328ca> in <module>
# ----> 1 data=pd.read_csv(tx)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv(tx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1118f55328ca> in <module>
# ----> 1 data=pd.read_csv(tx)
#
# NameError: name 'tx' is not defined

# %%
data=pd.read_csv(dt)

# %%
print(dt)
# Out:
# C:\Users\LG\Desktop\SUMMER1\Real_Property_Tax_-_2020.csv

# %%
print(data)
# Out:
#            CODE                  RESIDENCE           CITY  ZIP CODE    Value  \
# 0         45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 1        150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 2       1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 3        308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN    20100
# 4        311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN   236900
# ...         ...                        ...            ...       ...      ...
# 343908  3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0    40000
# 343909  3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0  5363000
# 343910  3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 343911  3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0        0
# 343912  3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN   151200
#
# ...

# %%
data.describe()
# Out:
#                CODE       ZIP CODE         Value       TAX-Due   WASTE-CHARGE  \
# count  3.439130e+05  324125.000000  3.439130e+05  3.439130e+05  343913.000000
# mean   1.937785e+06   20868.652890  5.811394e+05  5.675616e+03     264.230656
# std    1.109963e+06      62.088914  2.814134e+06  2.756035e+04    1086.661151
# min    1.100000e+01   12040.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    9.964400e+05   20851.000000  2.500000e+05  2.418860e+03      31.190000
# 50%    1.929071e+06   20874.000000  3.868000e+05  3.784410e+03     222.860000
# 75%    2.906532e+06   20901.000000  5.994000e+05  5.827260e+03     329.860000
# max    3.848226e+06   37215.000000  4.876059e+08  4.833150e+06  277605.200000
#
#             STATETAX         TOTAL       CREDITS     TOTAL-DUE
# count  343913.000000  3.439130e+05  3.439130e+05  3.439130e+05
# mean      649.614523  7.049641e+03  5.824979e+02  6.467143e+03
# std      3151.949184  3.334316e+04  4.018380e+03  3.284644e+04
# ...

# %%
tb=data.describe()

# %%
import matplotlib.pyplot as plt

# %%
data['RESIDENCE'].plot(kind='hist',bins=100)
plt.xlable('value')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-df1b15758c49> in <module>
# ----> 1 data['RESIDENCE'].plot(kind='hist',bins=100)
#       2 plt.xlable('value')
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
data['TOTAL'].plot(kind='hist',bins=100)
plt.xlable('value')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-17d1892cd6ab> in <module>
#       1 data['TOTAL'].plot(kind='hist',bins=100)
# ----> 2 plt.xlable('value')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
data['TOTAL'].plot(kind='hist',bins=100)
plt.xlable('CREDIT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-58c84952833e> in <module>
#       1 data['TOTAL'].plot(kind='hist',bins=100)
# ----> 2 plt.xlable('CREDIT')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
import matplotlib.pyplot as plt
data['TOTAL'].plot(kind='hist',bins=100)
plt.xlable('CREDIT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-2713f5ad37b6> in <module>
#       1 import matplotlib.pyplot as plt
#       2 data['TOTAL'].plot(kind='hist',bins=100)
# ----> 3 plt.xlable('CREDIT')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
import matplotlib.pyplot as plt
data['TOTAL'].plot(kind='hist',bins=100)
plt.xlable('TOTAL-DUE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1dfddd1d2397> in <module>
#       1 import matplotlib.pyplot as plt
#       2 data['TOTAL'].plot(kind='hist',bins=100)
# ----> 3 plt.xlable('TOTAL-DUE')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.TOTAL('100').min().plot(
    title='100 min TOTAL TAX'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-6e0e4e04930b> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 data.TOTAL('100').min().plot(
#       4     title='100 min TOTAL TAX'
#       5 )
#
# TypeError: 'Series' object is not callable

# %%
data.TOTAL.min().plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-2b82920704c1> in <module>
# ----> 1 data.TOTAL.min().plot()
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
from matplotlib.ticker import EngFormatter

# %%
data["TOTAL"].min().plot(kind="hist",bins=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-da93098fdb0e> in <module>
# ----> 1 data["TOTAL"].min().plot(kind="hist",bins=100)
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
from matplotlib.ticker import EngFormatter

TOTAL = data.groupby(pd.Grouper(freq='10')).sum().TOTAL

ax = TOTAL.plot(title='TOTAL', figsize=(10, 4))
ax.set_ylabel('TOTAL TAX')
ax.yaxis.set_major_formatter(EngFormatter())

over_1M = TOTAL[TOTAL >= 0


ax.legend()
# Out:
#   File "<ipython-input-34-f492167aebb8>", line 12
#     ax.legend()
#     ^
# SyntaxError: invalid syntax

# %%
from matplotlib.ticker import EngFormatter

TOTAL = data.groupby(pd.Grouper(freq='10')).sum().TOTAL

ax = TOTAL.plot(title='TOTAL', figsize=(10, 4))
ax.set_ylabel('TOTAL TAX')
ax.yaxis.set_major_formatter(EngFormatter())

over_1M = TOTAL[TOTAL >= 0
# Out:
#   File "<ipython-input-35-f492167aebb8>", line 12
#     ax.legend()
#     ^
# SyntaxError: invalid syntax

# %%
from matplotlib.ticker import EngFormatter

TOTAL = data.groupby(pd.Grouper(freq='10')).sum().TOTAL

ax = TOTAL.plot(title='TOTAL', figsize=(10, 4))
ax.set_ylabel('TOTAL TAX')
ax.yaxis.set_major_formatter(EngFormatter())

over_1M = TOTAL[TOTAL >= 0
# Out:
#   File "<ipython-input-36-992f75905a2e>", line 9
#     over_1M = TOTAL[TOTAL >= 0
#                               ^
# SyntaxError: unexpected EOF while parsing

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')['VALUE'].sum()
plot_data.sort_values()[-10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-86eb5d2131fe> in <module>
#       1 plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
# ----> 2 plot_data=plot_data.groupby('ZIP CODE')['value'].sum()
#       3 plot_data.sort_values()[-10:].plot(kind='bar')
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("TEST")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
# ...

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')['VALUE'].sum()
plot_data.sort_values()[-10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-71462964eb19> in <module>
#       1 plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
# ----> 2 plot_data=plot_data.groupby('ZIP CODE')['VALUE'].sum()
#       3 plot_data.sort_values()[-10:].plot(kind='bar')
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("TEST")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
# ...

# %%
print(data)
# Out:
#            CODE                  RESIDENCE           CITY  ZIP CODE    Value  \
# 0         45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 1        150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 2       1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 3        308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN    20100
# 4        311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN   236900
# ...         ...                        ...            ...       ...      ...
# 343908  3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0    40000
# 343909  3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0  5363000
# 343910  3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 343911  3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0        0
# 343912  3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN   151200
#
# ...

# %%
print(plot_data)
# Out:
#            CODE            RESIDENCE            CITY  ZIP CODE   Value  \
# 35       932938  PRINCIPAL RESIDENCE        DAMASCUS   20872.0  499833
# 40       944787  PRINCIPAL RESIDENCE        DAMASCUS   20872.0  404467
# 52      1324403  PRINCIPAL RESIDENCE   SILVER SPRING   20902.0  405467
# 54      2949440  PRINCIPAL RESIDENCE       ROCKVILLE   20852.0    8000
# 56      1329644  PRINCIPAL RESIDENCE   SILVER SPRING   20902.0  359633
# ...         ...                  ...             ...       ...     ...
# 343870  3807740  PRINCIPAL RESIDENCE      CLARKSBURG       NaN  364067
# 343874  3808915  PRINCIPAL RESIDENCE  NORTH BETHESDA   20852.0  640000
# 343887  3801663  PRINCIPAL RESIDENCE        BETHESDA   20814.0  536667
# 343894  3803800  PRINCIPAL RESIDENCE             NaN       NaN  378767
# 343908  3811057  PRINCIPAL RESIDENCE        BETHESDA   20814.0   40000
#
#          TAX-Due  WASTE-CHARGE  STATETAX    TOTAL  CREDITS   TOTAL-DUE
# ...

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')['VALUE'].sum()
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-d19c28d4830f> in <module>
#       1 plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
# ----> 2 plot_data=plot_data.groupby('ZIP CODE')['VALUE'].sum()
#       3 plt.title("Top 10 Tax")
#       4 plt.ylabel("TEST")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# ...

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# Text(0, 0.5, 'TEST')

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')
plot_data.sort_values()[10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-0e74289204ba> in <module>
#       1 plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
#       2 plot_data=plot_data.groupby('ZIP CODE')
# ----> 3 plot_data.sort_values()[10:].plot(kind='bar')
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("TEST")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')
plot_data.plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')
plot_data.plot(kind='hist',bins=100)
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3e880106f45c> in <module>
# ----> 1 plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
#       2 plot_data=plot_data.groupby('ZIP CODE')
#       3 plot_data.plot(kind='hist',bins=100)
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("TEST")
#
# NameError: name 'data' is not defined

# %%
dt='C:\\Users\\LG\\Desktop\SUMMER1\\Real_Property_Tax_-_2020.csv'

# %%
data=pd.read_csv(dt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c874b996c042> in <module>
# ----> 1 data=pd.read_csv(dt)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(dt)

# %%
print(data)
# Out:
#            CODE                  RESIDENCE           CITY  ZIP CODE    Value  \
# 0         45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 1        150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 2       1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 3        308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN    20100
# 4        311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN   236900
# ...         ...                        ...            ...       ...      ...
# 343908  3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0    40000
# 343909  3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0  5363000
# 343910  3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 343911  3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0        0
# 343912  3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN   151200
#
# ...

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')
plot_data.plot(kind='hist',bins=100)
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Text(0, 0.5, 'TEST')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
dt='C:\\Users\\LG\\Desktop\SUMMER1\\Real_Property_Tax_-_2020.csv'
data=pd.read_csv(dt)

# %%
print(data)
# Out:
#            CODE                  RESIDENCE           CITY  ZIP CODE    Value  \
# 0         45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 1        150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 2       1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 3        308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN    20100
# 4        311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN   236900
# ...         ...                        ...            ...       ...      ...
# 343908  3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0    40000
# 343909  3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0  5363000
# 343910  3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN        0
# 343911  3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0        0
# 343912  3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN   151200
#
# ...

# %%
data['TOTAL-DUE'].plot(kind='hist',bins=1000)
plt.xlable('TOTAL TAX DUE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TOTAL-DUE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-90d0b8d4199f> in <module>
# ...

# %%
data.TOTAL.plot(kind='hist',bins=1000)
plt.xlable('TOTAL TAX DUE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-bf7e76858bf9> in <module>
#       1 data.TOTAL.plot(kind='hist',bins=1000)
# ----> 2 plt.xlable('TOTAL TAX DUE')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
tx='C:\\Users\\LG\\Desktop\SUMMER1\\FAO.csv'
data1=pd.read_csv(tx)

# %%
print(data1)
# Out:
#       Area  Code     AreaName  ItemCode                      Item  \
# 0      AFG     2  Afghanistan      2511        Wheat and products
# 1      AFG     2  Afghanistan      2805  Rice (Milled Equivalent)
# 2      AFG     2  Afghanistan      2513       Barley and products
# 3      AFG     2  Afghanistan      2513       Barley and products
# 4      AFG     2  Afghanistan      2514        Maize and products
# ...    ...   ...          ...       ...                       ...
# 21472  ZWE   181     Zimbabwe      2948   Milk - Excluding Butter
# 21473  ZWE   181     Zimbabwe      2960             Fish, Seafood
# 21474  ZWE   181     Zimbabwe      2960             Fish, Seafood
# 21475  ZWE   181     Zimbabwe      2961   Aquatic Products, Other
# 21476  ZWE   181     Zimbabwe      2928             Miscellaneous
#
#        ElementCode Element         Unit  latitude  longitude  ...   Y2011  \
# 0             5142    Food  1000 tonnes     33.94      67.71  ...  3249.0
# ...

# %%
data1['latitude'].plot(kind='hist',bins=100)
plt.xlable('latitude Value')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-223113070ec8> in <module>
#       1 data1['latitude'].plot(kind='hist',bins=100)
# ----> 2 plt.xlable('latitude Value')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
data.TOTAL.plot(kind='hist',bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.Value.plot(kind='hist',bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data1['latitude'].plot(kind='hist',bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plot_data=data1[data1['Element']=='FOOD']
plot_data=plot_data.groupby('Area')['Y2015'].sum()
plot_data.sort_values()[-10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ellement'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-7d82863d7f45> in <module>
# ...

# %%
plot_data=data1[data1['Element']=='FOOD']
plot_data=plot_data.groupby('Area')['Y2015'].sum()
plot_data.sort_values()[-10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-d261cf4d2a87> in <module>
#       1 plot_data=data1[data1['Element']=='FOOD']
#       2 plot_data=plot_data.groupby('Area')['Y2015'].sum()
# ----> 3 plot_data.sort_values()[-10:].plot(kind='bar')
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("TEST")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
plot_data1=data1[data1['Element']=='FOOD']
plot_data1=plot_data.groupby('Area')['Y2015'].sum()
plot_data1.sort_values()[-10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("Food produced (Tones)")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-ac7ecfde6c5c> in <module>
#       1 plot_data=data1[data1['Element']=='FOOD']
#       2 plot_data=plot_data.groupby('Area')['Y2015'].sum()
# ----> 3 plot_data.sort_values()[-10:].plot(kind='bar')
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("Food produced (Tones)")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
plot_data1=data1[data1['Element']=='FOOD']
plot_data1=plot_data.groupby('Area')['Y2015'].sum()
plot_data1.sort_values()[-10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("Food produced (Tones)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-5d8c9fa6b5dc> in <module>
#       1 plot_data1=data1[data1['Element']=='FOOD']
# ----> 2 plot_data1=plot_data.groupby('Area')['Y2015'].sum()
#       3 plot_data1.sort_values()[-10:].plot(kind='bar')
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("Food produced (Tones)")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# --> 280                 raise KeyError(f"Column not found: {key}")
#     281             return self._gotitem(key, ndim=1)
#     282
#
# KeyError: 'Column not found: Y2015'

# %%
plot_data1=data1[data1['Element']=='FOOD']
plot_data1=plot_data.groupby('Area')['Y2015'].sum()
plot_data1.sort_values()[-10:].plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("Food produced (Tones)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-5d8c9fa6b5dc> in <module>
#       1 plot_data1=data1[data1['Element']=='FOOD']
# ----> 2 plot_data1=plot_data.groupby('Area')['Y2015'].sum()
#       3 plot_data1.sort_values()[-10:].plot(kind='bar')
#       4 plt.title("Top 10 Tax")
#       5 plt.ylabel("Food produced (Tones)")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# --> 280                 raise KeyError(f"Column not found: {key}")
#     281             return self._gotitem(key, ndim=1)
#     282
#
# KeyError: 'Column not found: Y2015'

# %%
plot_data=data[data['CITY']=='BETHESDA']
plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Top 10 Tax")
plt.ylabel("TEST")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: -10.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-2dcdbd343a15> in <module>
# ...

# %%
plot_data=data[data['CITY']=='BETHESDA']
plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zipe code")
plt.ylabel("Total Tax")
# Out:
# Text(0, 0.5, 'TEST')

# %%
plot_data=data[data['CITY']=='BETHESDA']
plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zipe code")
plt.ylabel("Total Tax")
# Out:
# Text(0, 0.5, 'Total Tax')

# %%
plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zip code")
plt.ylabel("Total Tax")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-47df4a1206c5> in <module>
# ----> 1 plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
#       2 plot_data.plot(kind='bar')
#       3 plt.title("Total tax of each zipe code")
#       4 plt.ylabel("Total Tax")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# --> 280                 raise KeyError(f"Column not found: {key}")
#     281             return self._gotitem(key, ndim=1)
#     282
#
# KeyError: 'Column not found: TOTAL'

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zipe code")
plt.ylabel("Total Tax")
# Out:
# Text(0, 0.5, 'Total Tax')

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('CITY')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zipe code")
plt.ylabel("Total Tax")
# Out:
# Text(0, 0.5, 'Total Tax')

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('CITY')['CREDITS'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zip code")
plt.ylabel("Total Tax Due")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-799eab39b09b> in <module>
#       1 plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
# ----> 2 plot_data=plot_data.groupby('CITY')['TOTAL-DUE'].sum()
#       3 plot_data.plot(kind='bar')
#       4 plt.title("Total tax of each zip code")
#       5 plt.ylabel("Total Tax Due")
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\users\lg\desktop\summer1\final\myenv\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
# ...

# %%
plot_data=data[data['RESIDENCE']=='PRINCIPAL RESIDENCE']
plot_data=plot_data.groupby('ZIP CODE')['CREDITS'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zip code")
plt.ylabel("Total Tax Due")
# Out:
# Text(0, 0.5, 'Total Tax Due')

# %%
plot_data=data[data['CITY']=='BETHESDA']
plot_data=plot_data.groupby('ZIP CODE')['CREDITS'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zip code")
plt.ylabel("Total Tax Due")
# Out:
# Text(0, 0.5, 'Total Tax Due')

# %%
plot_data=data[data['CITY']=='BETHESDA']
plot_data=plot_data.groupby('ZIP CODE')['CREDITS'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zip code")
plt.ylabel("Total Tax Due")
# Out:
# Text(0, 0.5, 'Total Tax Due')

# %%
plot_data=data[data['CITY']=='GERMANTOWN']
plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zip code")
plt.ylabel("Total Tax Due")
# Out:
# Text(0, 0.5, 'Total Tax Due')

# %%
plot_data=data[data['CITY']=='GERMANTOWN']
plot_data=plot_data.groupby('ZIP CODE')['TOTAL'].sum()
plot_data.plot(kind='bar')
plt.title("Total tax of each zip code")
plt.ylabel("Total Tax Due")
# Out:
# Text(0, 0.5, 'Total Tax Due')
