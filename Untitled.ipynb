# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Tax_Revenue_By_Month.csv'

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
pd.read_csv(df)
# Out:
#       ID      Month  Calendar Year  Income Tax Estimates & Finals  \
# 0      1       July           2011                            NaN
# 1      2     August           2011                   2.320268e+07
# 2      3  September           2011                   2.748813e+08
# 3      4    October           2011                   6.944227e+07
# 4      5   November           2011                   8.803835e+07
# ..   ...        ...            ...                            ...
# 114  115    January           2021                   5.240746e+08
# 115  116   February           2021                   3.777888e+07
# 116  117      March           2021                   8.047873e+07
# 117  118      April           2021                   5.143920e+08
# 118  119        May           2021                   1.011470e+09
#
#      Sales and Use  Business Use  Business Entity  Real Estate Conveyance  \
# 0              NaN           NaN        381060.92                     NaN
# ...

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5cc0934cc03c> in <module>
# ----> 1 df.dtypes
#
# AttributeError: 'str' object has no attribute 'dtypes'

# %%
df2 = df[['Month', 'Calendar Year', 'Total Revenue']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-bbeedac594c1> in <module>
# ----> 1 df2 = df[['Month', 'Calendar Year', 'Total Revenue']]
#
# TypeError: string indices must be integers

# %%
import numpy as np
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Real_Property_Tax_-_2020.csv'

# %%
pd.read_csv(df)
# Out:
#         PARCEL CODE                  RESIDENCE           CITY  ZIP CODE  \
# 0             45986  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 1            150491  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 2           1624601  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 3            308418  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 4            311347  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# ...             ...                        ...            ...       ...
# 343908      3811057        PRINCIPAL RESIDENCE       BETHESDA   20814.0
# 343909      3815580  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0
# 343910      3835645  NOT A PRINCIPAL RESIDENCE            NaN       NaN
# 343911      3806530  NOT A PRINCIPAL RESIDENCE  SILVER SPRING   20910.0
# 343912      3826388  NOT A PRINCIPAL RESIDENCE            NaN       NaN
#
#           Value  COUNTY PROPERTY TAX-Due  SOLID WASTE CHARGE  \
# ...

# %%
df2 = df[['RESIDENCE', 'CITY', 'TOTAL-DUE']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-9929dfb7790f> in <module>
# ----> 1 df2 = df[['RESIDENCE', 'CITY', 'TOTAL-DUE']]
#
# TypeError: string indices must be integers

# %%
import numpy as np
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Tax_Revenue_By_Month.csv'

# %%
pd.read_csv(df)
# Out:
#       ID      Month  Calendar Year  Income Tax Estimates & Finals  \
# 0      1       July           2011                            NaN
# 1      2     August           2011                   2.320268e+07
# 2      3  September           2011                   2.748813e+08
# 3      4    October           2011                   6.944227e+07
# 4      5   November           2011                   8.803835e+07
# ..   ...        ...            ...                            ...
# 114  115    January           2021                   5.240746e+08
# 115  116   February           2021                   3.777888e+07
# 116  117      March           2021                   8.047873e+07
# 117  118      April           2021                   5.143920e+08
# 118  119        May           2021                   1.011470e+09
#
#      Sales and Use  Business Use  Business Entity  Real Estate Conveyance  \
# 0              NaN           NaN        381060.92                     NaN
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
fb.close.plot(kind='line', figsize=(10, 3))
plt.axvspan(
    '2018-07-25', '2018-07-31', alpha=0.2, label='July Revenue',
)
plt.ylabel('Price ($)')
plt.suptitle('July total')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-6a63cc73c5fe> in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 import seaborn as sns
#       6 fb.close.plot(kind='line', figsize=(10, 3))
#       7 plt.axvspan(
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# ...
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
fb.close.plot(kind='line', figsize=(10, 3))
plt.axvspan(
    '2018-07-25', '2018-07-31', alpha=0.2, label='July Revenue',
)
plt.ylabel('Price ($)')
plt.suptitle('July total')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6a63cc73c5fe> in <module>
#       4 import pandas as pd
#       5 import seaborn as sns
# ----> 6 fb.close.plot(kind='line', figsize=(10, 3))
#       7 plt.axvspan(
#       8     '2018-07-25', '2018-07-31', alpha=0.2, label='July Revenue',
#
# NameError: name 'fb' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
#df.close.plot(kind='line', figsize=(10, 3))
plt.axvspan(
    '2018-07-25', '2018-07-31', alpha=0.2, label='July Revenue',
)
plt.ylabel('Price ($)')
plt.suptitle('July total')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d38cb65d9f02> in <module>
#       4 import pandas as pd
#       5 import seaborn as sns
# ----> 6 df.close.plot(kind='line', figsize=(10, 3))
#       7 plt.axvspan(
#       8     '2018-07-25', '2018-07-31', alpha=0.2, label='July Revenue',
#
# AttributeError: 'str' object has no attribute 'close'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
#df.close.plot(kind='line', figsize=(10, 3))
plt.axvspan(
    '2011-07-25', '2021-07-31', alpha=0.2, label='July Revenue',
)
plt.ylabel('Price ($)')
plt.suptitle('July total')
plt.legend()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
#df.close.plot(kind='line', figsize=(10, 3))
plt.axvspan(
    '2011-07-25', '2021-07-31', alpha=0.2, label='July Revenue',
)
plt.ylabel('Price ($)')
plt.suptitle('July total')
plt.legend()

# %%
n_rows = 2
n_cols = 2
fig, axes = plt.subplots(n_rows, n_cols)
for row_num in range(n_rows):
    for col_num in range(n_cols):
        ax = axes[row_num][col_num]
        ax.plot(np.random.rand(20))
        ax.set_title(f'Plot ({row_num+1}, {col_num+1})')
fig.suptitle('Tax Revenue')
fig.tight_layout()
plt.show()

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="password",
  database="mydatabase"
)

# %%
pip install ipython-sql

# %%
pip install mysqlclient

# %%
import pymysql

import pandas as a

conn=pymysql.connect(host='localhost',port=int(3306),user='sima',passwd='shahryar49',db='TaxOffice')

df=a.read_sql_query("SELECT * FROM 'AccountData' ",conn)

print(df)

# %%
print(df)

# %%
import pymysql

import pandas as a


conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='$Shahryar49$Shahryar49',db='iris')

df=a.read_sql_query("SELECT * FROM `iris-data`",conn)
print(df)

# %%
import pymysql

import pandas as a


conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='$Shahryar49$Shahryar49',db='iris')

df=a.read_sql_query("SELECT * FROM `iris-data`",conn)
print(df)

# %%
import pymysql

import pandas as a


conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='$Shahryar49$Shahryar49',db='iris')

a.read_sql_query("SELECT * FROM `iris-data`",conn)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from os import path
import requests
import time
import mysql.connector
from pathlib import Path
from datetime import datetime

mydb=mysql.connector.connect(
    host="localhost",
    user="taxoffice",
    password="7vGnSPoxPK4PbhLx",
    database="TaxOffice"

)
mycursor=mydb.cutsor()

print(mydb)

# %%
read (mydb)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from os import path
import requests
import time
import mysql.connector
from pathlib import Path
from datetime import datetime
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Tax_Revenue_By_Month.csv'
pd.read_csv(df)

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Tax_Revenue_By_Month.csv'

# %%
pd.read_csv(df)

# %%
import pandas as pd
import numpy as np
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Tax_Revenue_By_Month.csv'
pd.read_csv(df)

# %%
import pandas as pd
import numpy as np
df = 'C:\\Users\\LG\\Desktop\SUMMER1\\Tax_Revenue_By_Month.csv'
pd.read_csv(df)
